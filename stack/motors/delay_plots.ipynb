# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
import csv

with open('times.csv', 'r') as file:
    reader = csv.reader(file)
    data = next(reader)  # Read first (and only) row
    times = [float(x) for x in data]  # Convert strings to floats

import csv

with open('values.csv', 'r') as file:
    reader = csv.reader(file)
    values = [[float(x) for x in row] for row in reader]

times = np.array(times)
values = np.array(values)

# %%
plt.plot(times, values[:,0], label='Measured input')
print(len(times))
plt.scatter(times, values[:,0], label='Measured input')
plt.axhline(y=30, color='r', linestyle='--', label="Input reference")
plt.axvline(x=0, color='k', linestyle='-', alpha=0.2)
plt.xlabel("Delay [s]")
plt.ylabel("Input value")
# plt.xlim(-0.1, 0.5)
plt.xlim(-0.1, 0.1)
plt.title("Upper bound on delay")
plt.legend()
# Out:
# 1003

# %%
pts = [0.008859634399414062,0.013835906982421875,0.018803834915161133,0.028812170028686523,0.03881549835205078,0.04890012741088867,0.05879640579223633,0.06883716583251953,0.0788114070892334,0.0888211727142334,0.0989077091217041,0.10880017280578613,0.11883020401000977,0.12879133224487305,0.13882184028625488,0.14888477325439453,0.1588153839111328,0.16886377334594727,0.1788182258605957,0.18884587287902832,0.1989133358001709,0.2088170051574707,0.21886134147644043,0.22881650924682617,0.23882222175598145,0.24890947341918945,0.25880908966064453,0.26885151863098145,0.2788124084472656,0.28881049156188965,0.2988591194152832,0.3088061809539795,0.31885290145874023,0.3288083076477051,0.33881497383117676,0.34889888763427734,0.35880208015441895,0.3688161373138428,0.3788015842437744,0.388775110244751,0.39882612228393555,0.4087858200073242,0.4187774658203125,0.42888498306274414,0.43884944915771484,0.44890618324279785,0.45884013175964355,0.4688572883605957,0.4788215160369873,0.4888474941253662,0.4988820552825928,0.5088353157043457,0.5188517570495605,0.5288105010986328,0.5388436317443848,0.548898458480835,0.5588154792785645,0.5688469409942627,0.5788707733154297,0.5888490676879883,0.5990734100341797,0.6088647842407227,0.6188676357269287,0.6290156841278076,0.6388454437255859,0.6490724086761475,0.6588308811187744,0.6688742637634277,0.6788535118103027,0.6888580322265625,0.6988732814788818,0.7088265419006348,0.7188568115234375,0.7288558483123779,0.7388513088226318,0.7488687038421631,0.7588207721710205,0.7688534259796143,0.778825044631958,0.7888531684875488,0.7988696098327637,0.8088243007659912,0.818854808807373,0.8288233280181885,0.8388495445251465,0.8488984107971191,0.8588449954986572,0.868884801864624,0.8788819313049316,0.8888809680938721,0.8989381790161133,0.9088597297668457,0.9188737869262695,0.9291183948516846,0.9388642311096191,0.9489033222198486,0.9588625431060791,0.9688873291015625,0.9788644313812256,0.9888584613800049,0.9988701343536377]
print(len(pts))
# Out:
# 101
