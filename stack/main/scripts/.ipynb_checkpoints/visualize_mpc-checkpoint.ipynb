# %%
import re
import ast
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys, os

sys.path.append("/Users/paulleonardwolff/Desktop/trunk-stack/stack/main/src/executor/executor")
from reference_generator import ReferenceTrajectoryGenerator

# %%
def latex_label(text):
    """
    Converts regular text to a LaTeX-compatible label, handling LaTeX math mode correctly.
    """
    # Split text into math ($...$) and non-math segments
    parts = re.split(r'(\$.+?\$)', text)
    formatted_parts = []

    for part in parts:
        if part.startswith('$') and part.endswith('$'):
            # It's a math mode segment, add it as is
            formatted_parts.append(part)
        else:
            # Replace spaces with ~ and wrap non-math text with \mathrm{}
            clean_fragment = part.replace(' ', '~')
            if clean_fragment:
                latex_command = r"\mathrm{" + clean_fragment + "}"
                formatted_parts.append(f'${latex_command}$')
                # formatted_parts.append(f'${r"\mathrm{" + clean_fragment + "}"}$')

    return ''.join(formatted_parts)

# %%
def plot_controls_only(ts, u_mpc):
    """
    Plot only the control inputs over time.
    
    Args:
        ts (np.ndarray): Time array.
        u_mpc (np.ndarray): Control input array with shape (timesteps, 1, control_dim).
    """
    fig, ax = plt.subplots(figsize=(8, 4))

    for u_idx in range(u_mpc.shape[-1]):
        # Style by index
        if u_idx == 0 or u_idx == 5:
            linestyle = '-'    # Solid
        elif u_idx == 1 or u_idx == 3:
            linestyle = '--'   # Dashed
        elif u_idx == 2 or u_idx == 4:
            linestyle = '-.'   # Dash-dot
        else:
            linestyle = ':'    # Dotted fallback

        ax.plot(ts, u_mpc[:, 0, u_idx], label=latex_label(f'u_{u_idx+1}(t)'), linestyle=linestyle)

    ax.set_xlabel(latex_label('t [s]'))
    ax.set_ylabel(latex_label('U'))
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def set_axes_equal(ax):
    """
    Make axes of 3D plot have equal scale so that spheres appear as spheres,
    cubes as cubes, etc.

    Input
      ax: a matplotlib axis, e.g., as output from plt.gca().
    """

    x_limits = ax.get_xlim3d()
    y_limits = ax.get_ylim3d()
    z_limits = ax.get_zlim3d()

    x_range = abs(x_limits[1] - x_limits[0])
    x_middle = np.mean(x_limits)
    y_range = abs(y_limits[1] - y_limits[0])
    y_middle = np.mean(y_limits)
    z_range = abs(z_limits[1] - z_limits[0])
    z_middle = np.mean(z_limits)

    # The plot bounding box is a sphere in the sense of the infinity
    # norm, hence I call half the max range the plot radius.
    plot_radius = 0.5*max([x_range, y_range, z_range])

    ax.set_xlim3d([x_middle - plot_radius, x_middle + plot_radius])
    ax.set_ylim3d([y_middle - plot_radius, y_middle + plot_radius])
    ax.set_zlim3d([z_middle - plot_radius, z_middle + plot_radius])

# %%
def plot_mpc_trajectory(ts, z_ref, z_mpc, z_true, u_mpc, N, plot_controls=True, topdown=False):
    """
    Plot the MPC trajectory for 2D or 3D data.
    """
    # Determine the dimension (2D or 3D)
    dim = z_ref.shape[1]

    # Set up the plotting environment
    if plot_controls:
        if dim == 2:
            fig, ax = plt.subplots(1, 2, figsize=(10, 4))
        else:
            fig = plt.figure(figsize=(12, 5))
            ax = [fig.add_subplot(1, 2, 1, projection='3d'), fig.add_subplot(1, 2, 2)]
    else:
        if dim == 2:
            fig, ax = plt.subplots(1, 1, figsize=(6, 4))
            ax = [ax]
        else:
            fig = plt.figure(figsize=(6, 5))
            ax = [fig.add_subplot(1, 1, 1, projection='3d')]

    # Plot the MPC trajectories
    for t_idx in range(len(ts) - 2 * N):
        if dim == 2:
            ax[0].plot(z_mpc[t_idx, :, 0], z_mpc[t_idx, :, 1], '--*', color='k', markersize=3,
                       label=latex_label('MPC') if t_idx == 0 else None)
        else:
            ax[0].plot3D(z_mpc[t_idx, :, 0], z_mpc[t_idx, :, 1], z_mpc[t_idx, :, 2], '--*', color='k', markersize=3,
                         label=latex_label('MPC') if t_idx == 0 else None)

    # Plot the true trajectory, start point, and reference
    if dim == 2:
        ax[0].plot(z_true[:-N, 0], z_true[:-N, 1], '-o', label=latex_label('True'), markersize=3)
        ax[0].plot(z_true[0, 0], z_true[0, 1], 'ro', label=latex_label('Start'), markersize=6)
        ax[0].plot(z_ref[:-N, 0], z_ref[:-N, 1], 'y--', label=latex_label('Reference'))
        ax[0].set_xlabel(latex_label('X [m]'))
        ax[0].set_ylabel(latex_label('Y [m]'))
        ax[0].axis('equal')
    else:
        ax[0].plot3D(z_true[:-N, 0], z_true[:-N, 1], z_true[:-N, 2], '-o', label=latex_label('True'), markersize=3)
        ax[0].scatter(z_true[0, 0], z_true[0, 1], z_true[0, 2], color='r', label=latex_label('Start'), s=36)
        ax[0].plot3D(z_ref[:-N, 0], z_ref[:-N, 1], z_ref[:-N, 2], 'y--', label=latex_label('Reference'), markersize=3)
        # ax[0].scatter(z_ref[:-N, 0], z_ref[:-N, 1], z_ref[:-N, 2], color='y', label=latex_label('Reference'), s=40)
        ax[0].set_xlabel(latex_label('X [m]'))
        ax[0].set_ylabel(latex_label('Y [m]'))
        ax[0].set_zlabel(latex_label('Z [m]'))
        ax[0].set_box_aspect([1, 1, 1])
        if topdown:
            ax[0].view_init(elev=180, azim=-90, roll=-0)
        else:
            ax[0].view_init(elev=115, azim=-115, roll=-25)
        set_axes_equal(ax[0])
    ax[0].legend()

    # Plot the control inputs
    if plot_controls:
        for u_idx in range(u_mpc.shape[-1]):
            # Determine the line style based on the index
            if u_idx == 0 or u_idx == 5:
                linestyle = '-'  # Full line for 1 and 6
            elif u_idx == 1 or u_idx == 3:
                linestyle = '--'  # Dashed line for 2 and 4
            elif u_idx == 2 or u_idx == 4:
                linestyle = '-.'  # Double dashed line for 3 and 5
        
            ax[1].plot(ts, u_mpc[:, 0, u_idx], label=latex_label(f'u_{u_idx+1}(t)'), linestyle=linestyle)
        # for u_idx in range(u_mpc.shape[-1]):
        #     ax[1].plot(ts, u_mpc[:, 0, u_idx], label=latex_label(f'u_{u_idx+1}(t)'))
        ax[1].set_xlabel(latex_label('t [s]'))
        ax[1].set_ylabel(latex_label('U'))
        ax[1].legend()

    plt.tight_layout()

def plot_mpc_trajectory_new_2(ts, z_ref, z_mpc, z_true, u_mpc, N,
                             plot_controls=True, topdown=False,
                             interactive=False, dark_mode=False):
    if dark_mode:
        plt.style.use('dark_background')
    plt.ion() if interactive else plt.ioff()

    # pick open-loop color
    loop_color = '#666666' if dark_mode else 'lightgrey'
    # pick true‐trajectory color
    true_color = 'orange' if dark_mode else 'k'

    dim = z_ref.shape[1]
    # ——— Trajectory figure ———
    fig1 = plt.figure(figsize=(5, 5))
    ax  = fig1.add_subplot(1, 1, 1, projection='3d' if dim == 3 else None)
    ax.grid(True)
    if dim == 2:
        ax.set_aspect('equal', 'box'); plot = ax.plot
    else:
        ax.set_box_aspect([1]*3);       plot = ax.plot3D
        ax.view_init(180, -90) if topdown else ax.view_init(115, -115, roll=-25)

    # open-loop preds
    if z_mpc.ndim == 3:
        for i in range(len(ts) - 2*N):
            coords = [z_mpc[i, :, j] for j in range(dim)]
            plot(*coords, '--*', color=loop_color, ms=3,
                 label='Open-loop' if i == 0 else None)
    else:
        plot(*[z_mpc[:, j] for j in range(dim)],
             '--*', color=loop_color, ms=3, label='Open-loop')

    # true trajectory + start
    if dim == 2:
        ax.plot(z_true[:-N,0], z_true[:-N,1], '-o',
                color=true_color, ms=3, label='True')
        ax.plot(z_true[0,0],   z_true[0,1],   'ro', ms=6, label='Start')
    else:
        ax.plot3D(z_true[:-N,0], z_true[:-N,1], z_true[:-N,2],
                  '-o', color=true_color, ms=3, label='True')
        ax.scatter(*z_true[0], color='r', s=36, label='Start')

    # reference
    plot(*[z_ref[:-N, j] for j in range(dim)], '--', color='b', label='Ref')

    ax.set(xlabel='X [m]', ylabel='Y [m]' + (', Z [m]' if dim == 3 else ''))
    ax.legend()
    fig1.tight_layout()

    # ——— Controls figure ———
    if plot_controls:
        fig2, ax2 = plt.subplots(figsize=(6, 4), constrained_layout=True)
        fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)

        ax2.grid(True)
        for i in range(u_mpc.shape[-1]):
            ls = ['-','--','-.'][i % 3]
            ax2.plot(ts, u_mpc[:, 0, i], ls=ls, label=f'$u_{{{i+1}}}$')
        ax2.set(xlabel='t [s]', ylabel='U')
        ax2.legend()

    if interactive:
        plt.show()
    else:
        plt.show(block=False)

# %%
config = {
            "mpc": {
                "dt": 0.04
            },
            "trajectory": {
                "type": "eight",  # Options: "circle", "circle_with_ramp", "eight", "pacman", "flower"
                "duration": 20.0,  # Duration of the simulation in seconds
                "speed": 0.5,  # Angular speed (rad/s)
                "include_velocity": False,
                "parameters": {
                    "center": [0.0, 0.0],  # Center of the (x,y) trajectory
                    "radius": 0.05,  # [m]  For "circle" and "pacman"
                    "amplitude": 0.05,  # [m]  For "eight"
                    "z_level": 0.0,  # [m]  Constant z-coordinate
                    "mouth_angle": 0.7854  # [rad] Defines the size of the pacman mouth (default π/4)
                }
            },
            "delay_embedding": {
                "perf_var_dim": 3,
                "also_embedd_u": True
            },
            # "model": "sim_origin_best.pkl"
            "model": "first_mpc_model_real_trunk.pkl"
        }

mpc_config, traj_config = config["mpc"], config["trajectory"]

ref_traj = ReferenceTrajectoryGenerator(traj_config, mpc_config["dt"])
ref_traj.sample_trajectory(traj_config["duration"])

reference_trajectory = ref_traj.trajectory

# %%
#N = 10
#n_x = 5
#n_z = 3
#n_u = 2

N = 2
n_x = 119
n_z = 3
n_u = 2
# mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/mpc_U04-dU0-Q50-Qzf100-R0001-0005-001-N{N}-4D-small_figure_eight.csv')
# mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/mpc_Rdu005.csv')
# mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/test_experiment.csv')
mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/test_experiment_koopman.csv')


topt_pd, xopt_pd, uopt_pd, zopt_pd = mpc_test_data['topt'], mpc_test_data['xopt'], mpc_test_data['uopt'], mpc_test_data['zopt']
num_samples = len(topt_pd)
topt_np = np.zeros((num_samples, N+1))
xopt_np = np.zeros((num_samples, N+1, n_x))
uopt_np = np.zeros((num_samples, N, n_u))
zopt_np = np.zeros((num_samples, N+1, n_z))
for sample_idx in range(num_samples):
    topt_list = ast.literal_eval(topt_pd[sample_idx].strip('"'))
    topt_np[sample_idx, :] = topt_list
    xopt_list = ast.literal_eval(xopt_pd[sample_idx].strip('"'))
    xopt_np[sample_idx, :] = np.array(xopt_list).reshape(-1, n_x)
    uopt_list = ast.literal_eval(uopt_pd[sample_idx].strip('"'))
    uopt_np[sample_idx, :] = np.array(uopt_list).reshape(-1, n_u)
    zopt_list = ast.literal_eval(zopt_pd[sample_idx].strip('"'))
    zopt_np[sample_idx, :] = np.array(zopt_list).reshape(-1, n_z)

# %%
plot_controls_only(topt_np[:,0], uopt_np)

# %%
N = 2
n_x = 119
n_z = 3
n_u = 2
n_y = 12

### Circles:
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_koopman_circle_1_05.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_koopman_circle_5_05.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_koopman_circle_8_05.csv') # <- REDO without U limits

### Eights:
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_koopman_eight_3_05.csv')
mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_koopman_eight_5_05.csv')

topt_pd, xopt_pd, uopt_pd, zopt_pd, y_pd = mpc_cl_data['topt'], mpc_cl_data['xopt'], mpc_cl_data['uopt'], mpc_cl_data['zopt'], mpc_cl_data['y']
num_samples = len(topt_pd)
topt_np = np.zeros((num_samples, N+1))
xopt_np = np.zeros((num_samples, N+1, n_x))
uopt_np = np.zeros((num_samples, N, n_u))
zopt_np = np.zeros((num_samples, N+1, n_z))
y_np = np.zeros((num_samples, n_y))
for sample_idx in range(num_samples):
    topt_list = ast.literal_eval(topt_pd[sample_idx].strip('"'))
    topt_np[sample_idx, :] = topt_list
    xopt_list = ast.literal_eval(xopt_pd[sample_idx].strip('"'))
    xopt_np[sample_idx, :] = np.array(xopt_list).reshape(-1, n_x)
    uopt_list = ast.literal_eval(uopt_pd[sample_idx].strip('"'))
    uopt_np[sample_idx, :] = np.array(uopt_list).reshape(-1, n_u)
    zopt_list = ast.literal_eval(zopt_pd[sample_idx].strip('"'))
    zopt_np[sample_idx, :] = np.array(zopt_list).reshape(-1, n_z)
    y_list = ast.literal_eval(y_pd[sample_idx].strip('"'))
    y_np[sample_idx, :] = np.array(y_list).reshape(-1, n_y)

# %%
z_ref = reference_trajectory
#z_ref[:, [1, 2]] = z_ref[:, [2, 1]]
z_ref = z_ref[:, :2]


L = min(len(z_ref), y_np.shape[0])

diff = z_ref[:L] - y_np[:L, [0, 1]]
rmse = np.sqrt(np.mean(diff**2))
print(f"RMSE between z_ref and true z: {rmse:.3f}")

plot_mpc_trajectory_new_2(topt_np[:, 0], z_ref[:], zopt_np[:], y_np[:, :3], uopt_np, N, plot_controls=True, topdown=True, interactive=True, dark_mode=False)
# Out:
# RMSE between z_ref and true z: 0.052
# /var/folders/51/sy882xbj7sx1g7067_tfd0q40000gn/T/ipykernel_64501/190405278.py:129: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)

# %%
# SSM model:

N = 10
n_x = 5
n_z = 3
n_u = 2
n_y = 24

### Circles:
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_circle_5_05.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_circle_5_10.csv')

# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_circle_08_05.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_circle_10_05.csv')

### Eights:
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_eight_5_05.csv')
mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_eight_05_10.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/test_ssm_circle_5_05.csv')


topt_pd, xopt_pd, uopt_pd, zopt_pd, y_pd = mpc_cl_data['topt'], mpc_cl_data['xopt'], mpc_cl_data['uopt'], mpc_cl_data['zopt'], mpc_cl_data['y']
num_samples = len(topt_pd)
topt_np = np.zeros((num_samples, N+1))
xopt_np = np.zeros((num_samples, N+1, n_x))
uopt_np = np.zeros((num_samples, N, n_u))
zopt_np = np.zeros((num_samples, N+1, n_z))
y_np = np.zeros((num_samples, n_y))
for sample_idx in range(num_samples):
    topt_list = ast.literal_eval(topt_pd[sample_idx].strip('"'))
    topt_np[sample_idx, :] = topt_list
    xopt_list = ast.literal_eval(xopt_pd[sample_idx].strip('"'))
    xopt_np[sample_idx, :] = np.array(xopt_list).reshape(-1, n_x)
    uopt_list = ast.literal_eval(uopt_pd[sample_idx].strip('"'))
    uopt_np[sample_idx, :] = np.array(uopt_list).reshape(-1, n_u)
    zopt_list = ast.literal_eval(zopt_pd[sample_idx].strip('"'))
    zopt_np[sample_idx, :] = np.array(zopt_list).reshape(-1, n_z)
    y_list = ast.literal_eval(y_pd[sample_idx].strip('"'))
    y_np[sample_idx, :] = np.array(y_list).reshape(-1, n_y)

# %%
z_ref = reference_trajectory
#z_ref[:, [1, 2]] = z_ref[:, [2, 1]]
z_ref = z_ref[:, :2]


L = min(len(z_ref), y_np.shape[0])

diff = z_ref[:L] - y_np[:L, [0, 1]]
rmse = np.sqrt(np.mean(diff**2))
print(f"RMSE between z_ref and true z: {rmse:.3f}")

plot_mpc_trajectory_new_2(topt_np[:, 0], z_ref[:], zopt_np[:], y_np[:, :3], uopt_np, N, plot_controls=True, topdown=True, interactive=True, dark_mode=False)
# Out:
# RMSE between z_ref and true z: 0.052
# /var/folders/51/sy882xbj7sx1g7067_tfd0q40000gn/T/ipykernel_64501/66938433.py:129: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)
