# %%
import re
import ast
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('TkAgg')   # or 'Qt5Agg', depending on what you have installed
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

import sys, os

sys.path.append("/Users/paulleonardwolff/Desktop/trunk-stack/stack/main/src/executor/executor") # for the laptop
# sys.path.append("XXX") # for the workstation

from reference_generator import ReferenceTrajectoryGenerator

# %% [markdown]
# # Define functions:

# %%
def latex_label(text):
    """
    Converts regular text to a LaTeX-compatible label, handling LaTeX math mode correctly.
    """
    # Split text into math ($...$) and non-math segments
    parts = re.split(r'(\$.+?\$)', text)
    formatted_parts = []

    for part in parts:
        if part.startswith('$') and part.endswith('$'):
            # It's a math mode segment, add it as is
            formatted_parts.append(part)
        else:
            # Replace spaces with ~ and wrap non-math text with \mathrm{}
            clean_fragment = part.replace(' ', '~')
            if clean_fragment:
                latex_command = r"\mathrm{" + clean_fragment + "}"
                formatted_parts.append(f'${latex_command}$')
                # formatted_parts.append(f'${r"\mathrm{" + clean_fragment + "}"}$')

    return ''.join(formatted_parts)

# %%
def set_axes_equal(ax):
    """
    Make axes of 3D plot have equal scale so that spheres appear as spheres,
    cubes as cubes, etc.

    Input
      ax: a matplotlib axis, e.g., as output from plt.gca().
    """

    x_limits = ax.get_xlim3d()
    y_limits = ax.get_ylim3d()
    z_limits = ax.get_zlim3d()

    x_range = abs(x_limits[1] - x_limits[0])
    x_middle = np.mean(x_limits)
    y_range = abs(y_limits[1] - y_limits[0])
    y_middle = np.mean(y_limits)
    z_range = abs(z_limits[1] - z_limits[0])
    z_middle = np.mean(z_limits)

    # The plot bounding box is a sphere in the sense of the infinity
    # norm, hence I call half the max range the plot radius.
    plot_radius = 0.5*max([x_range, y_range, z_range])

    ax.set_xlim3d([x_middle - plot_radius, x_middle + plot_radius])
    ax.set_ylim3d([y_middle - plot_radius, y_middle + plot_radius])
    ax.set_zlim3d([z_middle - plot_radius, z_middle + plot_radius])

# %%
def plot_controls_only(ts, u_mpc):
    """
    Plot only the control inputs over time.
    
    Args:
        ts (np.ndarray): Time array.
        u_mpc (np.ndarray): Control input array with shape (timesteps, 1, control_dim).
    """
    fig, ax = plt.subplots(figsize=(8, 4))

    for u_idx in range(u_mpc.shape[-1]):
        # Style by index
        if u_idx == 0 or u_idx == 5:
            linestyle = '-'    # Solid
        elif u_idx == 1 or u_idx == 3:
            linestyle = '--'   # Dashed
        elif u_idx == 2 or u_idx == 4:
            linestyle = '-.'   # Dash-dot
        else:
            linestyle = ':'    # Dotted fallback

        ax.plot(ts, u_mpc[:, 0, u_idx], label=latex_label(f'u_{u_idx+1}(t)'), linestyle=linestyle)

    ax.set_xlabel(latex_label('t [s]'))
    ax.set_ylabel(latex_label('U'))
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    plt.show()


def plot_mpc_trajectory(ts, z_ref, z_mpc, z_true, u_mpc, N,
                        plot_controls=True, topdown=False, interactive=False):
    if interactive: plt.ion()
    else:           plt.ioff()

    dim = z_ref.shape[1]
    # setup axes
    if plot_controls:
        if dim==2: fig, ax = plt.subplots(1,2,figsize=(10,4))
        else:
            fig = plt.figure(figsize=(12,5))
            ax = [fig.add_subplot(1,2,1,projection='3d'),
                  fig.add_subplot(1,2,2)]
    else:
        if dim==2: fig, ax0 = plt.subplots(1,1,figsize=(6,4)); ax=[ax0]
        else:      fig = plt.figure(figsize=(6,5)); ax=[fig.add_subplot(1,1,1,projection='3d')]

    # plot MPC
    if z_mpc.ndim==3:
        for i in range(len(ts)-2*N):
            if dim==2:
                ax[0].plot(z_mpc[i,:,0],z_mpc[i,:,1],'--*',markersize=3,
                           label=latex_label('MPC') if i==0 else None)
            else:
                ax[0].plot3D(z_mpc[i,:,0],z_mpc[i,:,1],z_mpc[i,:,2],'--*',
                             markersize=3,label=latex_label('MPC') if i==0 else None)
    else:
        if dim==2:
            ax[0].plot(z_mpc[:,0],z_mpc[:,1],'--*',markersize=3,label=latex_label('MPC'))
        else:
            ax[0].plot3D(z_mpc[:,0],z_mpc[:,1],z_mpc[:,2],'--*',markersize=3,
                         label=latex_label('MPC'))

    # true, start & ref
    if dim==2:
        ax[0].plot(z_true[:-N,0],z_true[:-N,1],'-o',markersize=3,label=latex_label('True'))
        ax[0].plot(z_true[0,0],z_true[0,1],'ro',markersize=6,label=latex_label('Start'))
        ax[0].plot(z_ref[:-N,0],z_ref[:-N,1],'y--',label=latex_label('Reference'))
        ax[0].set(xlabel=latex_label('X [m]'),ylabel=latex_label('Y [m]')); ax[0].axis('equal')
    else:
        ax[0].plot3D(z_true[:-N,0],z_true[:-N,1],z_true[:-N,2],'-o',markersize=3,label=latex_label('True'))
        ax[0].scatter(z_true[0,0],z_true[0,1],z_true[0,2],color='r',s=36,label=latex_label('Start'))
        ax[0].plot3D(z_ref[:-N,0],z_ref[:-N,1],z_ref[:-N,2],'y--',markersize=3,label=latex_label('Reference'))
        ax[0].set(xlabel=latex_label('X [m]'),ylabel=latex_label('Y [m]'),zlabel=latex_label('Z [m]'))
        ax[0].set_box_aspect([1,1,1])
        if topdown: ax[0].view_init(elev=180,azim=-90)
        else:       ax[0].view_init(elev=115,azim=-115,roll=-25)
        set_axes_equal(ax[0])
    ax[0].legend()

    # controls
    if plot_controls:
        for ui in range(u_mpc.shape[-1]):
            ls = '-' if ui in {0,5} else '--' if ui in {1,3} else '-.'
            ax[1].plot(ts, u_mpc[:,0,ui],label=latex_label(f'u_{ui+1}(t)'),linestyle=ls)
        ax[1].set(xlabel=latex_label('t [s]'),ylabel=latex_label('U')); ax[1].legend()

    plt.tight_layout()
    plt.show() if interactive else plt.show(block=False)

def plot_mpc_trajectory_new(ts, z_ref, z_mpc, z_true, u_mpc, N,
                            plot_controls=True, topdown=False, interactive=False):
    """
    Plot MPC open-loop predictions, true trajectory, and reference with
    standardized styles.
    """
    if interactive:
        plt.ion()
    else:
        plt.ioff()

    dim = z_ref.shape[1]
    # choose figure & axes
    if plot_controls:
        if dim == 2:
            fig, ax = plt.subplots(1, 2, figsize=(10, 4))
        else:
            fig = plt.figure(figsize=(12, 5))
            ax = [
                fig.add_subplot(1, 2, 1, projection='3d'),
                fig.add_subplot(1, 2, 2),
            ]
    else:
        if dim == 2:
            fig, ax0 = plt.subplots(1, 1, figsize=(6, 4))
            ax = [ax0]
        else:
            fig = plt.figure(figsize=(6, 5))
            ax = [fig.add_subplot(1, 1, 1, projection='3d')]

    # 1) open-loop MPC predictions in light grey
    if z_mpc.ndim == 3:
        for i in range(len(ts) - 2 * N):
            if dim == 2:
                ax[0].plot(
                    z_mpc[i, :, 0],
                    z_mpc[i, :, 1],
                    '--*',
                    color='lightgrey',
                    markersize=3,
                    label='Open-loop preds' if i == 0 else None,
                )
            else:
                ax[0].plot3D(
                    z_mpc[i, :, 0],
                    z_mpc[i, :, 1],
                    z_mpc[i, :, 2],
                    '--*',
                    color='lightgrey',
                    markersize=3,
                    label='Open-loop preds' if i == 0 else None,
                )
    else:
        if dim == 2:
            ax[0].plot(
                z_mpc[:, 0],
                z_mpc[:, 1],
                '--*',
                color='lightgrey',
                markersize=3,
                label='Open-loop preds',
            )
        else:
            ax[0].plot3D(
                z_mpc[:, 0],
                z_mpc[:, 1],
                z_mpc[:, 2],
                '--*',
                color='lightgrey',
                markersize=3,
                label='Open-loop preds',
            )

    # 2) true trajectory in black
    if dim == 2:
        ax[0].plot(
            z_true[:-N, 0],
            z_true[:-N, 1],
            '-o',
            color='black',
            markersize=3,
            label='True trajectory',
        )
        # start marker (optional)
        ax[0].plot(
            z_true[0, 0],
            z_true[0, 1],
            'ro',
            markersize=6,
            label='Start',
        )
    else:
        ax[0].plot3D(
            z_true[:-N, 0],
            z_true[:-N, 1],
            z_true[:-N, 2],
            '-o',
            color='black',
            markersize=3,
            label='True trajectory',
        )
        ax[0].scatter(
            z_true[0, 0],
            z_true[0, 1],
            z_true[0, 2],
            color='r',
            s=36,
            label='Start',
        )

    # 3) reference trajectory in blue dashed
    if dim == 2:
        ax[0].plot(
            z_ref[:-N, 0],
            z_ref[:-N, 1],
            '--',
            color='blue',
            label='Reference',
        )
        ax[0].set(xlabel='X [m]', ylabel='Y [m]')
        ax[0].axis('equal')
    else:
        ax[0].plot3D(
            z_ref[:-N, 0],
            z_ref[:-N, 1],
            z_ref[:-N, 2],
            '--',
            color='blue',
            markersize=3,
            label='Reference',
        )
        ax[0].set(xlabel='X [m]', ylabel='Y [m]', zlabel='Z [m]')
        ax[0].set_box_aspect([1, 1, 1])
        if topdown:
            ax[0].view_init(elev=180, azim=-90)
        else:
            ax[0].view_init(elev=115, azim=-115, roll=-25)
        # if you have a helper to equalize axes in 3D, call it here:
        # set_axes_equal(ax[0])

    ax[0].legend()

    # 4) controls (unchanged)
    if plot_controls:
        for ui in range(u_mpc.shape[-1]):
            ls = '-' if ui in {0, 5} else '--' if ui in {1, 3} else '-.'
            ax[1].plot(
                ts,
                u_mpc[:, 0, ui],
                label=f'$u_{{{ui+1}}}(t)$',
                linestyle=ls,
            )
        ax[1].set(xlabel='t [s]', ylabel='U')
        ax[1].legend()

    plt.tight_layout()
    if interactive:
        plt.show()
    else:
        plt.show(block=False)

def plot_mpc_trajectory_new_2(ts, z_ref, z_mpc, z_true, u_mpc, N,
                             plot_controls=True, topdown=False,
                             interactive=False, dark_mode=False):
    if dark_mode:
        plt.style.use('dark_background')
    plt.ion() if interactive else plt.ioff()

    # pick open-loop color
    loop_color = '#666666' if dark_mode else 'lightgrey'
    # pick true‐trajectory color
    true_color = 'orange' if dark_mode else 'k'

    dim = z_ref.shape[1]
    # ——— Trajectory figure ———
    fig1 = plt.figure(figsize=(5, 5))
    ax  = fig1.add_subplot(1, 1, 1, projection='3d' if dim == 3 else None)
    ax.grid(True)
    if dim == 2:
        ax.set_aspect('equal', 'box'); plot = ax.plot
    else:
        ax.set_box_aspect([1]*3);       plot = ax.plot3D
        ax.view_init(180, -90) if topdown else ax.view_init(115, -115, roll=-25)

    # open-loop preds
    if z_mpc.ndim == 3:
        for i in range(len(ts) - 2*N):
            coords = [z_mpc[i, :, j] for j in range(dim)]
            plot(*coords, '--*', color=loop_color, ms=3,
                 label='Open-loop' if i == 0 else None)
    else:
        plot(*[z_mpc[:, j] for j in range(dim)],
             '--*', color=loop_color, ms=3, label='Open-loop')

    # true trajectory + start
    if dim == 2:
        ax.plot(z_true[:-N,0], z_true[:-N,1], '-o',
                color=true_color, ms=3, label='True')
        ax.plot(z_true[0,0],   z_true[0,1],   'ro', ms=6, label='Start')
    else:
        ax.plot3D(z_true[:-N,0], z_true[:-N,1], z_true[:-N,2],
                  '-o', color=true_color, ms=3, label='True')
        ax.scatter(*z_true[0], color='r', s=36, label='Start')

    # reference
    plot(*[z_ref[:-N, j] for j in range(dim)], '--', color='b', label='Ref')

    ax.set(xlabel='X [m]', ylabel='Y [m]' + (', Z [m]' if dim == 3 else ''))
    ax.legend()
    fig1.tight_layout()

    # ——— Controls figure ———
    if plot_controls:
        fig2, ax2 = plt.subplots(figsize=(6, 4), constrained_layout=True)
        fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)

        ax2.grid(True)
        for i in range(u_mpc.shape[-1]):
            ls = ['-','--','-.'][i % 3]
            ax2.plot(ts, u_mpc[:, 0, i], ls=ls, label=f'$u_{{{i+1}}}$')
        ax2.set(xlabel='t [s]', ylabel='U')
        ax2.legend()

    if interactive:
        plt.show()
    else:
        plt.show(block=False)

def compute_rmse_time_aligned(ts_ref, z_ref, ts_true, z_true):
    """
    Interpolates z_ref to match timestamps of z_true and computes RMSE (x, y).
    
    Parameters:
        ts_ref: (N,) time values for reference trajectory
        z_ref: (N, 2) reference positions (x, y)
        ts_true: (M,) time values for true trajectory
        z_true: (M, >=2) true positions (x, y, ...)
    
    Returns:
        rmse: scalar RMSE value in meters
    """
    # Debug prints
    print(f"[DEBUG] ts_ref shape: {ts_ref.shape}")
    print(f"[DEBUG] z_ref shape: {z_ref.shape}")
    print(f"[DEBUG] ts_true shape: {ts_true.shape}")
    print(f"[DEBUG] z_true shape: {z_true.shape}")
    # Interpolate reference trajectory to true timestamps
    interp_ref_x = interp1d(ts_ref, z_ref[:, 0], kind='linear', fill_value="extrapolate")
    interp_ref_y = interp1d(ts_ref, z_ref[:, 1], kind='linear', fill_value="extrapolate")

    z_ref_interp = np.stack([
        interp_ref_x(ts_true),
        interp_ref_y(ts_true)
    ], axis=1)

    # Calculate RMSE
    diff = z_ref_interp - z_true[:, :2]
    rmse = np.sqrt(np.mean(diff**2))
    return rmse


def plot_time_aligned_trajectory_comparison(ts_ref, z_ref, ts_true, z_true, dim_labels=('x', 'y', 'z')):
    """
    Interpolates reference trajectory to match true timestamps and plots
    each dimension (x, y, z) over time for comparison.

    Parameters:
        ts_ref: (N,) time vector for reference trajectory
        z_ref: (N, d) reference positions
        ts_true: (M,) time vector for true trajectory
        z_true: (M, d) true positions
        dim_labels: tuple of str, labels for each dimension
    """

    # Sanity checks
    if z_ref.shape[1] != z_true.shape[1]:
        raise ValueError(f"Dimension mismatch: z_ref has {z_ref.shape[1]} dims, z_true has {z_true.shape[1]} dims.")

    dims = z_ref.shape[1]

    # Interpolate each reference dimension
    z_ref_interp = []
    for i in range(dims):
        interp = interp1d(ts_ref, z_ref[:, i], kind='linear', fill_value="extrapolate")
        z_ref_interp.append(interp(ts_true))
    z_ref_interp = np.stack(z_ref_interp, axis=1)  # shape (M, d)

    # Plotting
    fig, axes = plt.subplots(dims, 1, figsize=(8, 2.5 * dims), sharex=True)
    if dims == 1:
        axes = [axes]

    for i in range(dims):
        ax = axes[i]
        ax.plot(ts_true, z_true[:, i], 'k-', label='True')
        ax.plot(ts_true, z_ref_interp[:, i], 'b--', label='Reference')
        ax.set_ylabel(f"{dim_labels[i]} [m]")
        ax.grid(True)
        ax.legend()

    axes[-1].set_xlabel("Time [s]")
    fig.tight_layout()
    plt.show()

# %% [markdown]
# # New plotting function:

# %%
def plot_mpc_trajectory_thesis(
        ts, z_ref, z_mpc, z_true, u_mpc, N,
        plot_controls=True, topdown=False,
        interactive=False, dark_mode=False,
        # --- thesis-style additions ---
        figsize_mm=(120, 100), pixel_size=None, dpi=300,
        units='m',  # 'm' or 'mm'
        fixed_limits=None,     # (xmin, xmax, ymin, ymax) for 2D
        symmetric_axes=False,  # symmetric x/y about 0 (2D)
        axis_scale=None,       # global zoom factor for axis limits
        cutoff_index=None,     # truncate actual trajectory at this index (before removing last N)
        trajectory_color='blue'  # 'blue', 'red', or 'violet'
    ):
    import numpy as np
    import matplotlib.pyplot as plt

    # ---------- Trajectory color selection ----------
    traj_colors = {
        'blue': '#1f4e79',     # deep steel blue
        'red': '#b22222',      # firebrick red
        'violet': '#5d3a9b'    # muted royal violet
    }
    if trajectory_color.lower() not in traj_colors:
        raise ValueError(f"Invalid trajectory_color '{trajectory_color}'. "
                         f"Choose from {list(traj_colors.keys())}.")
    traversed_color = traj_colors[trajectory_color.lower()]

    # ---------- Styling ----------
    if dark_mode:
        plt.style.use('dark_background')
        loop_color = '#999999'          # open-loop preds
        true_color = 'grey'             # ground truth (dashed)
        start_marker = 'white'
    else:
        plt.style.use('default')
        loop_color = 'lightgrey'
        true_color = 'grey'
        start_marker = 'black'

    if pixel_size:
        figsize = (pixel_size[0]/dpi, pixel_size[1]/dpi)
    else:
        mm = 1/25.4
        figsize = (figsize_mm[0]*mm, figsize_mm[1]*mm)

    plt.rcParams.update({
        'font.size': 14,
        'axes.labelsize': 28,
        'legend.fontsize': 13,
        'xtick.labelsize': 13,
        'ytick.labelsize': 13,
        'pdf.fonttype': 42,
        'ps.fonttype': 42,
        'font.family': 'serif',
        'font.serif': ['Times New Roman']
    })

    plt.ion() if interactive else plt.ioff()

    dim = z_ref.shape[1]
    fig1 = plt.figure(figsize=figsize, dpi=dpi)
    ax = (fig1.add_subplot(1, 1, 1, projection='3d')
          if dim == 3 else
          fig1.add_subplot(1, 1, 1))

    # ---------- Cutoff logic ----------
    T = len(ts)

    # Actual trajectory cutoff (remove N prediction steps first, then apply cutoff_index)
    actual_end_idx = T
    if N is not None and N > 0:
        actual_end_idx = max(T - N, 0)
    if cutoff_index is not None:
        actual_end_idx = min(actual_end_idx, cutoff_index)
    actual_slic = slice(0, actual_end_idx)

    # Reference trajectory cutoff (only cutoff_index, no N removal)
    ref_end_idx = T if cutoff_index is None else min(T, cutoff_index)
    ref_slic = slice(0, ref_end_idx)

    # ---------- Unit scaling ----------
    scale = 1000.0 if units.lower() == 'mm' else 1.0
    z_ref_plot  = (z_ref.copy()  * scale)[ref_slic]
    z_true_plot = (z_true.copy() * scale)[actual_slic]
    ts_plot     = ts[actual_slic]

    if z_mpc.ndim == 3:
        z_mpc_plot = z_mpc.copy() * scale
    else:
        z_mpc_plot = (z_mpc.copy() * scale)[actual_slic]

    # ---------- Axes behavior ----------
    if dim == 2:
        ax.set_aspect('equal', 'box')
        ax.grid(False)
        plot_fn = ax.plot
        scatter_fn = ax.plot
    else:
        ax.set_box_aspect([1, 1, 1])
        ax.grid(True)
        plot_fn = ax.plot3D
        scatter_fn = ax.scatter
        if topdown:
            ax.view_init(180, -90)
        else:
            ax.view_init(115, -115, roll=-25)

    # ---------- Open-loop predictions (grey dashed) ----------
    if z_mpc.ndim == 3:
        max_i = max(len(ts_plot) - 2*N, 0)
        for i in range(max_i):
            coords = [z_mpc_plot[i, :, j] for j in range(dim)]
            if i < actual_end_idx:
                plot_fn(*coords, '--*', color=loop_color, ms=3,
                        label='Open-loop' if i == 0 else None)
    else:
        plot_fn(*[z_mpc_plot[:, j] for j in range(dim)],
                '--*', color=loop_color, ms=3, label='Open-loop')

    # ---------- Ground truth (grey dashed) ----------
    if dim == 2:
        ax.plot(z_ref_plot[:, 0], z_ref_plot[:, 1],
                linestyle='--', color=true_color, lw=1.8, label='Ground truth')
        ax.plot(z_ref_plot[0, 0], z_ref_plot[0, 1],
                marker='o', color=start_marker, ms=6, linestyle='None', zorder=5)
    else:
        ax.plot3D(z_ref_plot[:, 0], z_ref_plot[:, 1], z_ref_plot[:, 2],
                  linestyle='--', color=true_color, lw=1.8, label='Ground truth')
        ax.scatter(z_ref_plot[0, 0], z_ref_plot[0, 1], z_ref_plot[0, 2],
                   color=start_marker, s=36)

    # ---------- Actual trajectory (blue, thick) ----------
    if dim == 2:
        ax.plot(z_true_plot[:, 0], z_true_plot[:, 1],
                '-', color=traversed_color, lw=2.4, label='Trajectory')
        ax.plot(z_true_plot[:, 0], z_true_plot[:, 1],
                linestyle='None', marker='o', ms=3.5, color=traversed_color)
    else:
        ax.plot3D(z_true_plot[:, 0], z_true_plot[:, 1], z_true_plot[:, 2],
                  '-', color=traversed_color, lw=2.4, label='Trajectory')
        ax.scatter(z_true_plot[:, 0], z_true_plot[:, 1], z_true_plot[:, 2],
                   color=traversed_color, s=9)

    # ---------- Labels & Limits ----------
    unit_lbl = 'mm' if units.lower() == 'mm' else 'm'
    if dim == 2:
        ax.set_xlabel(f"x [{unit_lbl}]", fontsize=28)
        ax.set_ylabel(f"y [{unit_lbl}]", fontsize=28)
        ax.ticklabel_format(style='plain', axis='x')
        ax.ticklabel_format(style='plain', axis='y')
        ax.tick_params(axis='both', which='major', labelsize=20)

        # Fixed/symmetric limits
        if fixed_limits is not None:
            xmin, xmax, ymin, ymax = fixed_limits
        elif symmetric_axes:
            xs_list, ys_list = [], []
            xs_list.append(z_ref_plot[:, 0]); ys_list.append(z_ref_plot[:, 1])
            xs_list.append(z_true_plot[:, 0]); ys_list.append(z_true_plot[:, 1])
            if z_mpc.ndim == 2:
                xs_list.append(z_mpc_plot[:, 0]); ys_list.append(z_mpc_plot[:, 1])
            elif z_mpc.ndim == 3:
                if z_mpc_plot.shape[-1] >= 2:
                    xs_list.append(z_mpc_plot[..., 0].ravel())
                    ys_list.append(z_mpc_plot[..., 1].ravel())
                elif z_mpc_plot.shape[1] >= 2:
                    xs_list.append(z_mpc_plot[:, 0, :].ravel())
                    ys_list.append(z_mpc_plot[:, 1, :].ravel())
            xs = np.concatenate(xs_list)
            ys = np.concatenate(ys_list)
            m = np.isfinite(xs) & np.isfinite(ys)
            if m.any():
                r = max(np.max(np.abs(xs[m])), np.max(np.abs(ys[m])))
                xmin, xmax, ymin, ymax = -r, r, -r, r
            else:
                xmin, xmax, ymin, ymax = 0, 1, 0, 1
        else:
            xmin, xmax = ax.get_xlim()
            ymin, ymax = ax.get_ylim()

        # Apply axis scale factor
        if axis_scale is not None:
            cx, cy = (xmin + xmax) / 2, (ymin + ymax) / 2
            hx, hy = (xmax - xmin) / 2 * axis_scale, (ymax - ymin) / 2 * axis_scale
            xmin, xmax = cx - hx, cx + hx
            ymin, ymax = cy - hy, cy + hy

        ax.set_xlim(xmin, xmax)
        ax.set_ylim(ymin, ymax)

    else:
        ax.set_xlabel(f"X [{unit_lbl}]")
        ax.set_ylabel(f"Y [{unit_lbl}]")
        ax.set_zlabel(f"Z [{unit_lbl}]")
        # TODO: 3D axis scaling could be added similarly if needed

    fig1.tight_layout()

    # ---------- Controls figure ----------
    if plot_controls:
        fig2, ax2 = plt.subplots(figsize=(6, 4), constrained_layout=True, dpi=dpi)
        fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)
        ax2.grid(True)
        for i in range(u_mpc.shape[-1]):
            ls = ['-','--','-.'][i % 3]
            ax2.plot(ts_plot, u_mpc[actual_slic, 0, i], ls=ls, label=f'$u_{{{i+1}}}$')
        ax2.set(xlabel='t [s]', ylabel='U')
        ax2.legend()

    plt.show(block=not interactive)

# %%
import numpy as np
from typing import Optional, Dict, Any

def save_mpc_run_npz(
    path: str,
    *,
    ts_true: Optional[np.ndarray] = None,   # e.g. topt_np[:, 0]
    ts_ref: Optional[np.ndarray]  = None,   # e.g. timebase of reference_trajectory
    z_ref: Optional[np.ndarray]   = None,
    z_mpc: Optional[np.ndarray]   = None,
    z_true: Optional[np.ndarray]  = None,
    u_mpc: Optional[np.ndarray]   = None,
    N: Optional[int]              = None,
    rmse: Optional[float]         = None,
    meta: Optional[Dict[str, Any]] = None,
):
    """
    Save an MPC run to a compressed NPZ without enforcing matching lengths.
    Only non-None items are saved.
    """
    if not path.endswith(".npz"):
        raise ValueError("Path must end with '.npz'")

    def _to_arr(x):
        return np.asarray(x) if x is not None else None

    payload = {
        "ts_true": _to_arr(ts_true),
        "ts_ref":  _to_arr(ts_ref),
        "z_ref":   _to_arr(z_ref),
        "z_mpc":   _to_arr(z_mpc),
        "z_true":  _to_arr(z_true),
        "u_mpc":   _to_arr(u_mpc),
        "N":       np.array(N, dtype=np.int32) if N is not None else None,
        "rmse":    np.array(rmse, dtype=float) if rmse is not None else None,
        "_schema_version": np.array("v2", dtype=object),
    }

    # serialize meta safely
    if meta is not None:
        try:
            import json
            payload["meta"] = np.array(json.dumps(meta), dtype=object)
        except Exception:
            payload["meta"] = np.array(str(meta), dtype=object)

    # Filter out None entries so file only contains what you pass
    payload = {k: v for k, v in payload.items() if v is not None}

    np.savez_compressed(path, **payload)


def load_mpc_run_npz(path: str):
    """
    Load an MPC run saved by save_mpc_run_npz.
    Returns a dict with arrays + parsed meta when possible.
    """
    out = {}
    with np.load(path, allow_pickle=True) as data:
        out["ts"] = data["ts"]
        out["z_ref"] = data["z_ref"]
        out["z_mpc"] = data["z_mpc"]
        out["z_true"] = data["z_true"]
        out["u_mpc"] = data["u_mpc"]
        out["N"] = int(data["N"])
        rmse_val = float(data["rmse"])
        out["rmse"] = None if np.isnan(rmse_val) else rmse_val
        out["_schema_version"] = str(data["_schema_version"])

        meta_raw = str(data["meta"])
        if meta_raw:
            try:
                import json
                out["meta"] = json.loads(meta_raw)
            except Exception:
                out["meta"] = meta_raw
        else:
            out["meta"] = {}

    return out

# %% [markdown]
# # Define reference traj:

# %%
# Generate reference trajectory (check that it's the same as used in mpc_initializer_node.py)
# z_ref, t = generate_ref_trajectory(10, 0.02, 'figure_eight', 0.08, dim=3)


config = {
            "mpc": {
                "dt": 0.02
            },
            "trajectory": {
                "type": "eight",  # Options: "circle", "circle_with_ramp", "eight", "pacman", "flower"
                "duration": 20.0,  # Duration of the simulation in seconds
                "speed": 1.0,  # Angular speed (rad/s)
                "include_velocity": False,
                "parameters": {
                    "center": [0.0, 0.0],  # Center of the (x,y) trajectory
                    "radius": 0.10,  # [m]  For "circle" and "pacman"
                    "amplitude": 0.05,  # [m]  For "eight"
                    "z_level": 0.0,  # [m]  Constant z-coordinate
                    "mouth_angle": 0.7854  # [rad] Defines the size of the pacman mouth (default π/4)
                }
            },
            "delay_embedding": {
                "perf_var_dim": 3,
                "also_embedd_u": True
            },
            # "model": "sim_origin_best.pkl"
            "model": "first_mpc_model_real_trunk.pkl"
        }

mpc_config, traj_config = config["mpc"], config["trajectory"]

ref_traj = ReferenceTrajectoryGenerator(traj_config, mpc_config["dt"])
ref_traj.sample_trajectory(traj_config["duration"])

reference_trajectory = ref_traj.trajectory

num_points = reference_trajectory.shape[0]
ts_ref = np.linspace(0, traj_config["duration"], num=num_points, endpoint=False)


# print("Reference trajectory shape:", reference_trajectory.shape)

# %%
N = 10
n_x = 7
n_z = 3
n_u = 2
# mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/mpc_U04-dU0-Q50-Qzf100-R0001-0005-001-N{N}-4D-small_figure_eight.csv')
# mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/mpc_Rdu005.csv')
# mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/pauls_first_test.csv')
mpc_test_data = pd.read_csv(f'../data/trajectories/test_mpc/pauls_second_test.csv')
topt_pd, xopt_pd, uopt_pd, zopt_pd = mpc_test_data['topt'], mpc_test_data['xopt'], mpc_test_data['uopt'], mpc_test_data['zopt']
num_samples = len(topt_pd)
topt_np = np.zeros((num_samples, N+1))
xopt_np = np.zeros((num_samples, N+1, n_x))
uopt_np = np.zeros((num_samples, N, n_u))
zopt_np = np.zeros((num_samples, N+1, n_z))
for sample_idx in range(num_samples):
    topt_list = ast.literal_eval(topt_pd[sample_idx].strip('"'))
    topt_np[sample_idx, :] = topt_list
    xopt_list = ast.literal_eval(xopt_pd[sample_idx].strip('"'))
    xopt_np[sample_idx, :] = np.array(xopt_list).reshape(-1, n_x)
    uopt_list = ast.literal_eval(uopt_pd[sample_idx].strip('"'))
    uopt_np[sample_idx, :] = np.array(uopt_list).reshape(-1, n_u)
    zopt_list = ast.literal_eval(zopt_pd[sample_idx].strip('"'))
    zopt_np[sample_idx, :] = np.array(zopt_list).reshape(-1, n_z)

z_true_dummy = zopt_np[:, :3]      # shape (N+1, n_z)
u_dummy      = uopt_np[0]      # shape (N,  n_u)

# %%
# %matplotlib widget
plot_controls_only(topt_np[:,0], uopt_np)

#plot_mpc_trajectory(topt_np[:,0], z_ref[:], zopt_np[:], z_true_dummy, uopt_np, N, plot_controls=True, topdown=True)

# %%
N = 10
n_x = 7
n_z = 3
n_u = 2


n_y = 40

### Circles
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_circle5_slow.csv') # included into thesis
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_circle5_mid.csv')  # included into thesis
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_circle5_mid_v2.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_circle5_faster.csv')

# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_circle8_slow_v2.csv') #include to thesis
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_circle10_slow_v2.csv') #include to thesis


### Pacman - Still check on them:
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_pacman_slow.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_pacman_mid.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_pacman_fast.csv')


### Eight - all speeds with 5cm
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight_slow.csv')
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight_slow_v2.csv')  # include into thesis
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight_mid.csv')  # <- looks ok
mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight_mid_v2.csv')  # include to thesis
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight_fast.csv')

## Eight - smaller
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight3_slow.csv') # <- looks ok
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight3_mid.csv') # <- looks ok
# mpc_cl_data = pd.read_csv(f'../data/trajectories/closed_loop/paul_51_v3_final_eight3_faster.csv')


topt_pd, xopt_pd, uopt_pd, zopt_pd, y_pd = mpc_cl_data['topt'], mpc_cl_data['xopt'], mpc_cl_data['uopt'], mpc_cl_data['zopt'], mpc_cl_data['y']
num_samples = len(topt_pd)
topt_np = np.zeros((num_samples, N+1))
xopt_np = np.zeros((num_samples, N+1, n_x))
uopt_np = np.zeros((num_samples, N, n_u))
zopt_np = np.zeros((num_samples, N+1, n_z))
y_np = np.zeros((num_samples, n_y))
for sample_idx in range(num_samples):
    topt_list = ast.literal_eval(topt_pd[sample_idx].strip('"'))
    topt_np[sample_idx, :] = topt_list
    xopt_list = ast.literal_eval(xopt_pd[sample_idx].strip('"'))
    xopt_np[sample_idx, :] = np.array(xopt_list).reshape(-1, n_x)
    uopt_list = ast.literal_eval(uopt_pd[sample_idx].strip('"'))
    uopt_np[sample_idx, :] = np.array(uopt_list).reshape(-1, n_u)
    zopt_list = ast.literal_eval(zopt_pd[sample_idx].strip('"'))
    zopt_np[sample_idx, :] = np.array(zopt_list).reshape(-1, n_z)
    y_list = ast.literal_eval(y_pd[sample_idx].strip('"'))
    y_np[sample_idx, :] = np.array(y_list).reshape(-1, n_y)

# %%
# %matplotlib widget
# plot_controls_only(topt_np[:, 0], uopt_np)


# --- Prepare inputs ---
ts_true = topt_np[:, 0]                 # timebase of the true trajectory / controls
ts_ref  = ts_ref  

z_ref = reference_trajectory[:, :2]         # 2D ref for plotting + saving
z_true = y_np[:, :3]                         # ground truth (3D here)
z_mpc  = zopt_np                             # open-loop predictions
u_mpc  = uopt_np
N_horizon = N


# RMSE (time-aligned)
rmse_koop = compute_rmse_time_aligned(ts_true, z_true, ts_ref, z_ref)
print("RMSE time aligned computed:", rmse_koop)

plot_mpc_trajectory_new_2(ts_true, z_ref, zopt_np[:], z_true, u_mpc, N_horizon, plot_controls=True, topdown=True, interactive=True, dark_mode=False)


save_mpc_run_npz(
    "mpc_run_006.npz",
    ts_true=ts_true,
    ts_ref=ts_ref,
    z_ref=z_ref,
    z_mpc=z_mpc,
    z_true=z_true,
    u_mpc=u_mpc,
    N=N_horizon,
    rmse=rmse_koop,
    meta={
        "units": {"space": "mm", "time": "s", "u": "arb"},
        "note": "baseline run, topdown=True",
        "cutoff_index_used": 500,
    },
)
# Out:
# [DEBUG] ts_ref shape: (275,)
# [DEBUG] z_ref shape: (275, 3)
# [DEBUG] ts_true shape: (1001,)
# [DEBUG] z_true shape: (1001, 2)
# RMSE time aligned computed: 0.008116362396715522
# /var/folders/51/sy882xbj7sx1g7067_tfd0q40000gn/T/ipykernel_97051/2409356239.py:306: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)

# %%
# %matplotlib inline

plot_mpc_trajectory_thesis(
    topt_np[:, 0],
    z_ref,          # plotted as the blue, thicker "traversed" path + blue dots
    zopt_np,        # open-loop segments (grey)
    y_np[:, :3],    # ground truth (grey dashed)
    uopt_np,
    N,
    fixed_limits=(-70, 70, -70, 70),  # (-60, 60, -60, 60), (-90, 90, -90, 90), (-120, 120, -120, 120), eight: (-70, 70, -70, 70)
    plot_controls=True,
    topdown=True,
    interactive=True,
    dark_mode=False,
    units='mm',
    figsize_mm=(360, 300),
    dpi=200,
    symmetric_axes=True,
    cutoff_index=330,  # 350, 205 , 330 , 330 # or an integer to truncate at that index
    trajectory_color='blue'  # 'blue', 'red', or 'violet'
)
# Out:
# /var/folders/51/sy882xbj7sx1g7067_tfd0q40000gn/T/ipykernel_97051/2283777329.py:202: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig2.subplots_adjust(left=0, right=1, bottom=0, top=1)

# %%
# 1) extract axes 0 & 2
pts = y_np[:300, [0, 1]]

# 2) plot
plt.figure(figsize=(6, 6))
plt.plot(pts[:, 0], pts[:, 1], '-o', markersize=4, label='Traversed trajectory')
plt.xlabel('State 0')
plt.ylabel('State 2')
plt.title('Ground Truth Trajectory (axes 0 & 2)')
plt.legend()
plt.grid(True)
plt.axis('equal')   # keep aspect ratio
plt.show()

# %%
# 1) extract axes 0 & 2
pts = z_ref[:300]

# 2) plot
plt.figure(figsize=(6, 6))
plt.plot(pts[:, 0], pts[:, 1], '-o', markersize=4, label='Ground Truth')
plt.xlabel('State 0')
plt.ylabel('State 2')
plt.title('Ground Truth Trajectory (axes 0 & 2)')
plt.legend()
plt.grid(True)
plt.axis('equal')   # keep aspect ratio
plt.show()
